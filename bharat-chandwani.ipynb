# %% [markdown]
# ## AASF + DSC IIITM Gwalior Presents 'Intro to Deep Learning & Kaggle' Session.

# %% [markdown]
# ### Hi !
# #### Welcome! This notebook is for the contest organized with the above session.

# %% [markdown]
# ### Instructions:
#
# 1. Clone this Github repo to run this notebook.
#
# 2. Run this notebook. You CAN use any platform ie **Kaggle, Colab etc...** to run the notebook.
#
# 3.  The notebook is well documented with all the necessay instructions provided in between. Kindly carefully read those instructions.
#
#
# **ANY SUBMISSION VIOLATING THE INSTRUCTIONS IS SUBJECT TO DISQUALIFICATION.**
#
# #### 4. ALL THE SUBMISSIONS WILL BE JUDGED FOR THEIR ACCURACY, CODE QUALITY etc. THE DECISION OF THE JUDGES SHALL BE FINAL & ABIDING ON ALL THE PARTICIPANTS.

# %% [markdown]
# ## CONTENTS ::

# %% [markdown]
# [ **1 ) Importing Various Modules**](#content1)

# %% [markdown]
# [ **2 ) Preparing the Data**](#content2)

# %% [markdown]
# [ **3 ) Modelling**](#content3)

# %% [markdown]
# [ **4 ) Evaluating the Model Performance**](#content4)

# %% [markdown]
# <a id="content1"></a>
# ## 1 ) Importing Various Modules.

# %% [markdown]
# #### The following cell is for importing the various modules required for coding.
#
# #### Some initial modules are loaded for you. If you require any other module, go ahead and import it !!!

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import tensorflow as tf

#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection and pre-processing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator

# keras 
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

# miscellaneous packages
import cv2                  
import numpy as np  
from tqdm import tqdm
import os 
import random as rn
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %% [markdown]
# <a id="content2"></a>
# ## 2 ) Preparing the Data

# %% [markdown]
# #### In this section, you will write the code to read and prepare the data. The dataset used for this contest is the [Flowers Recognition Dataset](https://www.kaggle.com/alxmamaev/flowers-recognition) on Kaggle.

# %% [markdown]
# ## 2.1) The Image Size.

# %% [markdown]
# #### In the cell below, the image size to be used is specified.
#
# ### For a fair judegment all the submissions need to use the same image size. Therefore, for this contest, the image size is fixed to 128.
#
# ### Any submission that uses an image size other than 128 is subject to disqualification.

# %%
IMG_SIZE = 128

# %% [markdown]
# ## 2.2) Reading the data.

# %% [markdown]
# #### In the following cell, provide the paths to the individual flower directories within the dataset.
#
# #### Currently the paths are according to the naming on Kaggle. So if you import the data in a noteboook on Kaggle or run this notebook on Kaggle and import the [dataset](https://www.kaggle.com/alxmamaev/flowers-recognition), the cell should work absolutely fine !!!
#
# #### If you are training on some other platform, like Google Colab or any other , specify the corresponding paths.

# %%
FLOWER_DAISY_DIR = '../input/flowers-recognition/flowers/daisy'
FLOWER_SUNFLOWER_DIR = '../input/flowers-recognition/flowers/sunflower'
FLOWER_TULIP_DIR = '../input/flowers-recognition/flowers/tulip'
FLOWER_DANDI_DIR = '../input/flowers-recognition/flowers/dandelion'
FLOWER_ROSE_DIR = '../input/flowers-recognition/flowers/rose'

# %% [markdown]
# ## 2.3) Reading the images and extracting the labels

# %% [markdown]
# #### The cell below creates 2 lists, one for the images and one for the labels. These lists will later be populated to hold the images and the corresponding labels.

# %%
X = [] # This array will hold all the images.

Y = [] # This list shall hold the labels for all the images.

# %% [markdown]
# #### The cell below has a function to read the data. Complete the function so that it correctly reads the images.

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=flower_type  # Assigning the label to this sample.
        path = os.path.join(DIR,img) # The path to the image.
        _, ftype = os.path.splitext(path)
        if ftype == ".jpg":# Just checking the file extension to be '.jpeg'
            
           #---------------------------------- X -----------------------------------#
           # Given the path to an image, read the image using OpenCV and resize it to have shape (128,128,3).
            
            img = cv2.imread(path, cv2.IMREAD_COLOR) # Write your code here.
            img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
           #---------------------------------- X ------------------------------------#
            
            # Append the image and the label to the respective lists.
            X.append(np.array(img)) 
            Y.append(str(label))

# %% [markdown]
# #### In the following lines of code, the above function has been called with appropriate parameters for each flower type.
#
# #### Once you have completed the above function, just run these cells to read and prepare the data. !!!

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
# Out:
# 100%|██████████| 769/769 [00:02<00:00, 338.15it/s]

# %%
make_train_data('Sunflower', FLOWER_SUNFLOWER_DIR)
# Out:
# 100%|██████████| 734/734 [00:02<00:00, 274.27it/s]

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
# Out:
# 100%|██████████| 984/984 [00:03<00:00, 305.70it/s]

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
# Out:
# 100%|██████████| 1055/1055 [00:03<00:00, 301.66it/s]

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
# Out:
# 100%|██████████| 784/784 [00:02<00:00, 330.46it/s]

# %%
print("The number of images is: ",len(X))
print("The number of labels is: ",len(Y))
# Out:
# The number of images is:  4323
# The number of labels is:  4323

# %% [markdown]
# ## 2.2 ) One Hot Encoding the Labels.

# %% [markdown]
# #### If you had been following since, you know that we have got a list named 'Y' that holds the labels.
#
# #### In the following cell, write the code to One Hot encode the labels.
#
# ### Note that the variable name of the One Hot Encoded labels should still be 'Y'. to proceed. Else you may have to change some portion of the code to follow.

# %%
#---------------------------------- X -----------------------------------#
# Given the set of labels Y, write code to One Hot Encode it. 
# Store the one hot encoded labels in variable named 'Y' only.
            

le = LabelEncoder()
Y  = le.fit_transform(Y)
Y  = to_categorical(Y,5)

#---------------------------------- X ------------------------------------#

# %% [markdown]
# ## 2.3) Normalize the images.

# %% [markdown]
# #### In the next cell, write code to normalize the images. If you had followed along, you know that we have a list 'X' that holds the images. Write code to normalize the images in the list.

# %%
#---------------------------------- X -----------------------------------#
# Given the images  in the list 'X', normalize them. Store the normalized images in variable named 'X' only.

X = np.array(X)
X = X / 255

#---------------------------------- X ------------------------------------#

# %% [markdown]
# ## 2.4) Splitting into Training and Validation Sets

# %% [markdown]
# #### Now we have the normalized images in 'X' and the corresponding labels in 'Y'.
#
# #### Use scikit learn [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) to create train and validation sets.
#
# ### Again, to be consistent across all the submissions, all the submissions have to use the same test size and random state.
#
# ### Use test_size=0.25 and random state=42.

# %%
#---------------------------------- X -----------------------------------#
# Given 'X' ie the images and 'Y' ie the labels, create the train and the validation sets. 

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 42)

#---------------------------------- X ------------------------------------#

# %% [markdown]
# <a id="content3"></a>
# ## 3 ) Modeling

# %% [markdown]
# #### In this section, you will actually build the model.
#
# ### A sample model has been provided in the cell below to start but note that all the submissions ARE free to experiment with the model architecture.
#
# ### You can freely play with the hyper-paramters such as **learning rate, etc..** and with other parameters such as the batch size, epochs, activation functions and others.

# %% [markdown]
# ## 3.1 ) Building the ConvNet Model

# %%
# A Sample CNN model.

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(128, 128, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same",strides=(2,2)))))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same",strides=(2,2)))))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same",strides=(2,2)))))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(5, activation="softmax"))

# %% [markdown]
# ## 3.2 ) The Batch size and the no. of Epochs.

# %%
# ------------ You can freely experiment with these parameters-----------------
batch_size = 32
epochs = 10

# %% [markdown]
# ## 3.3 ) Data Augmentation

# %% [markdown]
# #### If you understand the contents of the cell below, go ahead  and experiment with it !!!!
#
# #### Else just leave it as it is.

# %%
datagen = ImageDataGenerator(
        featurewise_center = False,  # set input mean to 0 over the dataset
        samplewise_center = False,  # set each sample mean to 0
        featurewise_std_normalization = False,  # divide inputs by std of the dataset
        samplewise_std_normalization = False,  # divide each input by its std
        zca_whitening = False,  # apply ZCA whitening
        rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range = 0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range = 0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip = False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ### You are free to use a different optimizer and different loss function and metrics.

# %% [markdown]
# ## 3.4 ) Compiling the Keras Model & Summary

# %%
model.compile(optimizer = Adam(lr = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# activation_12 (Activation)   (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 61, 61, 64)        18496
# _________________________________________________________________
# activation_13 (Activation)   (None, 61, 61, 64)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 29, 29, 128)       73856
# _________________________________________________________________
# activation_14 (Activation)   (None, 29, 29, 128)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 15, 15, 128)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               14746112
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 14,905,669
# Trainable params: 14,905,669
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3.5 ) Fitting on the Training set and making predictions on the Validation set

# %% [markdown]
# ### Don't change anything in this cell. The cell should work fine!!!

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch = x_train.shape[0] // batch_size)
# Out:
# Epoch 1/100
# 101/101 [==============================] - 14s 137ms/step - loss: 1.5247 - accuracy: 0.3308 - val_loss: 1.3508 - val_accuracy: 0.3895
# Epoch 2/100
# 101/101 [==============================] - 15s 146ms/step - loss: 1.2369 - accuracy: 0.4620 - val_loss: 1.1739 - val_accuracy: 0.4866
# Epoch 3/100
# 101/101 [==============================] - 13s 129ms/step - loss: 1.1119 - accuracy: 0.5402 - val_loss: 1.0592 - val_accuracy: 0.5846
# Epoch 4/100
# 101/101 [==============================] - 14s 137ms/step - loss: 1.0301 - accuracy: 0.5897 - val_loss: 0.9775 - val_accuracy: 0.6244
# Epoch 5/100
# 101/101 [==============================] - 13s 126ms/step - loss: 0.9799 - accuracy: 0.6143 - val_loss: 0.8842 - val_accuracy: 0.6448
# Epoch 6/100
# 101/101 [==============================] - 15s 144ms/step - loss: 0.9283 - accuracy: 0.6371 - val_loss: 0.8603 - val_accuracy: 0.6698
# Epoch 7/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.8761 - accuracy: 0.6679 - val_loss: 0.8649 - val_accuracy: 0.6568
# Epoch 8/100
# 101/101 [==============================] - 13s 127ms/step - loss: 0.8721 - accuracy: 0.6704 - val_loss: 0.8995 - val_accuracy: 0.6586
# Epoch 9/100
# 101/101 [==============================] - 13s 134ms/step - loss: 0.8497 - accuracy: 0.6745 - val_loss: 0.8518 - val_accuracy: 0.6716
# Epoch 10/100
# 101/101 [==============================] - 14s 140ms/step - loss: 0.8344 - accuracy: 0.6885 - val_loss: 0.7919 - val_accuracy: 0.6883
# Epoch 11/100
# 101/101 [==============================] - 14s 135ms/step - loss: 0.7997 - accuracy: 0.6913 - val_loss: 0.7718 - val_accuracy: 0.6975
# Epoch 12/100
# 101/101 [==============================] - 13s 125ms/step - loss: 0.7962 - accuracy: 0.6910 - val_loss: 0.7556 - val_accuracy: 0.7179
# Epoch 13/100
# 101/101 [==============================] - 13s 128ms/step - loss: 0.7701 - accuracy: 0.7081 - val_loss: 0.7951 - val_accuracy: 0.7003
# Epoch 14/100
# 101/101 [==============================] - 14s 141ms/step - loss: 0.7720 - accuracy: 0.7087 - val_loss: 0.7611 - val_accuracy: 0.7095
# Epoch 15/100
# 101/101 [==============================] - 14s 135ms/step - loss: 0.7625 - accuracy: 0.7212 - val_loss: 0.7365 - val_accuracy: 0.7253
# Epoch 16/100
# 101/101 [==============================] - 13s 133ms/step - loss: 0.7451 - accuracy: 0.7231 - val_loss: 0.7449 - val_accuracy: 0.7160
# Epoch 17/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.7441 - accuracy: 0.7206 - val_loss: 0.8151 - val_accuracy: 0.7012
# Epoch 18/100
# 101/101 [==============================] - 14s 139ms/step - loss: 0.7263 - accuracy: 0.7184 - val_loss: 0.7494 - val_accuracy: 0.7160
# Epoch 19/100
# 101/101 [==============================] - 14s 136ms/step - loss: 0.6916 - accuracy: 0.7405 - val_loss: 0.7356 - val_accuracy: 0.7290
# Epoch 20/100
# 101/101 [==============================] - 13s 129ms/step - loss: 0.6988 - accuracy: 0.7371 - val_loss: 0.6946 - val_accuracy: 0.7262
# Epoch 21/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.6880 - accuracy: 0.7452 - val_loss: 0.7328 - val_accuracy: 0.7216
# Epoch 22/100
# 101/101 [==============================] - 13s 129ms/step - loss: 0.6785 - accuracy: 0.7408 - val_loss: 0.7412 - val_accuracy: 0.7243
# Epoch 23/100
# 101/101 [==============================] - 14s 143ms/step - loss: 0.6781 - accuracy: 0.7520 - val_loss: 0.7056 - val_accuracy: 0.7364
# Epoch 24/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.6348 - accuracy: 0.7614 - val_loss: 0.6922 - val_accuracy: 0.7364
# Epoch 25/100
# 101/101 [==============================] - 13s 125ms/step - loss: 0.6595 - accuracy: 0.7489 - val_loss: 0.6856 - val_accuracy: 0.7410
# Epoch 26/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.6355 - accuracy: 0.7607 - val_loss: 0.6965 - val_accuracy: 0.7308
# Epoch 27/100
# 101/101 [==============================] - 13s 132ms/step - loss: 0.6187 - accuracy: 0.7648 - val_loss: 0.6400 - val_accuracy: 0.7687
# Epoch 28/100
# 101/101 [==============================] - 14s 140ms/step - loss: 0.6143 - accuracy: 0.7710 - val_loss: 0.7041 - val_accuracy: 0.7401
# Epoch 29/100
# 101/101 [==============================] - 13s 125ms/step - loss: 0.5975 - accuracy: 0.7695 - val_loss: 0.7257 - val_accuracy: 0.7179
# Epoch 30/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.6116 - accuracy: 0.7626 - val_loss: 0.6407 - val_accuracy: 0.7761
# Epoch 31/100
# 101/101 [==============================] - 12s 122ms/step - loss: 0.5869 - accuracy: 0.7838 - val_loss: 0.6348 - val_accuracy: 0.7650
# Epoch 32/100
# 101/101 [==============================] - 13s 129ms/step - loss: 0.5702 - accuracy: 0.7801 - val_loss: 0.6564 - val_accuracy: 0.7632
# Epoch 33/100
# 101/101 [==============================] - 14s 139ms/step - loss: 0.5786 - accuracy: 0.7801 - val_loss: 0.6637 - val_accuracy: 0.7641
# Epoch 34/100
# 101/101 [==============================] - 12s 124ms/step - loss: 0.5755 - accuracy: 0.7847 - val_loss: 0.6534 - val_accuracy: 0.7734
# Epoch 35/100
# 101/101 [==============================] - 13s 132ms/step - loss: 0.5554 - accuracy: 0.7916 - val_loss: 0.6252 - val_accuracy: 0.7724
# Epoch 36/100
# 101/101 [==============================] - 13s 126ms/step - loss: 0.5296 - accuracy: 0.8047 - val_loss: 0.7419 - val_accuracy: 0.7650
# Epoch 37/100
# 101/101 [==============================] - 14s 138ms/step - loss: 0.5464 - accuracy: 0.7941 - val_loss: 0.6467 - val_accuracy: 0.7752
# Epoch 38/100
# 101/101 [==============================] - 13s 132ms/step - loss: 0.5381 - accuracy: 0.7972 - val_loss: 0.6920 - val_accuracy: 0.7567
# Epoch 39/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.5461 - accuracy: 0.7984 - val_loss: 0.6488 - val_accuracy: 0.7872
# Epoch 40/100
# Epoch 82/100
# 101/101 [==============================] - 13s 131ms/step - loss: 0.3244 - accuracy: 0.8751 - val_loss: 0.6371 - val_accuracy: 0.8085
# Epoch 83/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.3561 - accuracy: 0.8685 - val_loss: 0.6822 - val_accuracy: 0.7891
# Epoch 84/100
# 101/101 [==============================] - 13s 131ms/step - loss: 0.3639 - accuracy: 0.8654 - val_loss: 0.6438 - val_accuracy: 0.8039
# Epoch 85/100
# 101/101 [==============================] - 12s 123ms/step - loss: 0.3107 - accuracy: 0.8860 - val_loss: 0.6390 - val_accuracy: 0.8057
# Epoch 86/100
# 101/101 [==============================] - 13s 131ms/step - loss: 0.3274 - accuracy: 0.8794 - val_loss: 0.6393 - val_accuracy: 0.7845
# Epoch 87/100
# 101/101 [==============================] - 13s 128ms/step - loss: 0.3315 - accuracy: 0.8785 - val_loss: 0.6624 - val_accuracy: 0.8020
# Epoch 88/100
# 101/101 [==============================] - 13s 127ms/step - loss: 0.3103 - accuracy: 0.8826 - val_loss: 0.6583 - val_accuracy: 0.8085
# Epoch 89/100
# 101/101 [==============================] - 13s 128ms/step - loss: 0.3274 - accuracy: 0.8829 - val_loss: 0.7098 - val_accuracy: 0.7909
# Epoch 90/100
# 101/101 [==============================] - 13s 125ms/step - loss: 0.3293 - accuracy: 0.8804 - val_loss: 0.5921 - val_accuracy: 0.7993
# Epoch 91/100
# 101/101 [==============================] - 14s 142ms/step - loss: 0.3030 - accuracy: 0.8847 - val_loss: 0.7191 - val_accuracy: 0.7900
# Epoch 92/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.2981 - accuracy: 0.8888 - val_loss: 0.7293 - val_accuracy: 0.7854
# Epoch 93/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.3120 - accuracy: 0.8807 - val_loss: 0.6627 - val_accuracy: 0.8094
# Epoch 94/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.3084 - accuracy: 0.8963 - val_loss: 0.6681 - val_accuracy: 0.8039
# Epoch 95/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.2878 - accuracy: 0.8928 - val_loss: 0.7417 - val_accuracy: 0.7872
# Epoch 96/100
# 101/101 [==============================] - 15s 144ms/step - loss: 0.2951 - accuracy: 0.8953 - val_loss: 0.6953 - val_accuracy: 0.7900
# Epoch 97/100
# 101/101 [==============================] - 13s 124ms/step - loss: 0.2785 - accuracy: 0.8922 - val_loss: 0.6914 - val_accuracy: 0.7946
# Epoch 98/100
# 101/101 [==============================] - 13s 130ms/step - loss: 0.2835 - accuracy: 0.8975 - val_loss: 0.7107 - val_accuracy: 0.7993
# Epoch 99/100
# 101/101 [==============================] - 13s 126ms/step - loss: 0.2848 - accuracy: 0.8988 - val_loss: 0.7311 - val_accuracy: 0.7946
# Epoch 100/100
# 101/101 [==============================] - 13s 128ms/step - loss: 0.2578 - accuracy: 0.9059 - val_loss: 0.7052 - val_accuracy: 0.8168

# %% [markdown]
# <a id="content4"></a>
# ## 4 ) Evaluating the Model Performance

# %% [markdown]
# #### This section is to evaluate the model that you have build.
#
# ### Just run the following two cells that plot the 'Model Loss vs Epochs' and the 'Model Accuracy vs Epochs'.

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss vs Epochs')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# #  THE END.
